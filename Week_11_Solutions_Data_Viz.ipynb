# %% [markdown]
# <a href="https://colab.research.google.com/github/CommunityRADvocate/ida3-fall24-colabs/blob/main/Week_11_Solutions_Data_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GCode Intro to Data Analytics
# ## Week 11 - Matplotlib, Data visualization, and Pandas (Solutions)

# %% [markdown]
# Welcome to the Python activities for this week! These activities have been designed to test and enhance your programming skills. In each challenge, you'll work on specific tasks, developing appropriate code structures.
#
# The objective of this exercise is to explore the new syntax and functions related to the matplotlib library that you learned throughout this week's track and to practice these concepts in real-world scenarios.

# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Activity 1. Analyzing Climate Data - Temperature and Precipitation Patterns
#
# Welcome to a hands-on journey into climate data analysis! In this activity, we'll use Matplotlib to investigate temperature and precipitation patterns. You'll learn how to visualize and interpret climate data, gaining valuable insights into our planet's climate. Let's dive in and discover what the data reveals about temperature and precipitation trends.
#
# <br>
#
# First, write a code that allows you to access the information contained in the csv file in the form of a pandas dataframe.
#
# Remember that each time you exit the collab you must upload the csv file again.

# %%
df = pd.read_csv("Prec_data.csv")

df.head()
# Out:
#          Date  Avg_Temperature_C  Total_Precipitation_mm
# 0  2022-01-01                3.5                    10.2
# 1  2022-01-02                4.2                     8.7
# 2  2022-01-03                5.1                     5.5
# 3  2022-01-04                6.2                     3.0
# 4  2022-01-05                7.3                     2.8

# %% [markdown]
# To get a better insight into how data visualization tools operate, we will work with the most common chart types that belong to the Matplotlib library:
#
# ## Task A: Line Graph
#
#  Make a line graph in which you can visualize how the average temperature and total precipitation values change over time. To do this, take only the data for the month of January.

# %%
# Extract data for the month of January
january_data = df.iloc[0:31]

# Extract the date, average temperature, and total precipitation columns
dates = january_data['Date']
avg_temperature = january_data['Avg_Temperature_C']
total_precipitation = january_data['Total_Precipitation_mm']

# Create a figure and set its size
plt.figure(figsize=(10, 6))

# Create a line plot for average temperature
plt.plot(dates, avg_temperature, label='Avg Temperature (°C)', color='blue', linestyle='-', marker='o')

# Create a line plot for total precipitation
plt.plot(dates, total_precipitation, label='Total Precipitation (mm)', color='green', linestyle='-', marker='s')

# Add a title and labels to the axes
plt.title('Climate Data for January 2022')
plt.xlabel('Date')
plt.ylabel('Value')

# Add a legend to the chart
plt.legend()

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Be sure to add style to the graphic, don't forget to:
# * Put a title to the figure and name the axis
# * Change the color of the lines
# * Choose the type of trace for each line
# * Add the legend of the chart
# * Change the size of the figure and so on

# %% [markdown]
#   ## Task B: Scatter Plot
#
#   Make a scatter plot between the **average temperature** and the **total  precipitation** in the whole dataset to verify if there is any relationship between these two variables. Again, do not forget to customize the graph with the characteristics mentioned above.

# %%
# Extract average temperature and total precipitation
avg_temperature = df['Avg_Temperature_C']
total_precipitation = df['Total_Precipitation_mm']

# Create a scatter plot
plt.figure(figsize=(8, 5))
plt.scatter(avg_temperature, total_precipitation, color='purple', marker='o', label='Data Points')

# Add a title and labels to the axes
plt.title('Scatter Plot of Average Temperature vs. Total Precipitation')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Total Precipitation (mm)')

# Add a legend
plt.legend()

# Customize the grid
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Question: Do you think it is possible to find a correlation by eye between the variables?
#
# <br>
#
# **Bonus:** Try to calculate the value of the correlation coefficient between the two variables, and conclude about the result.
#
# Remeber that it is a number between -1 and 1 that indicates how much two variables are related.
#
#   * If it is 1, it is a perfect positive relationship
#   * If it is -1 it is a perfect negative relationship
#   * If it is 0, there is no relationship at all
#
# ```
# corr_coef = df['Variable_1'].corr(df['Variable_2'])
# ```

# %%
corr_coef = df['Avg_Temperature_C'].corr(df['Total_Precipitation_mm'])
print(corr_coef)
# Out:
# 0.05349997633843582

# %% [markdown]
# The value is very close to zero, so in this case the average temperature has practically nothing to do with how much it rains in this area.

# %% [markdown]
# ##Task C: Create a Histogram for Temperature Data
#
# In this task, you will create a histogram for the temperature data in the DataFrame. *Pay attention to the number of bins required for an appropriate display of the data.* You can also consider creating subplots with different values for this parameter if you find it suitable, but it is not mandatory.
#
# <br>
# Customize the graph according to your preferences by modifying the parameters as desired.

# %%
# Extract temperature data
temperature_data = df['Avg_Temperature_C']

# Create a figure with subplots
plt.figure(figsize=(6, 8))

# First Subplot (10 Bins)
plt.subplot(3, 1, 1)
plt.hist(temperature_data, bins=10, color='skyblue', edgecolor='black')
plt.title('Bins: 10')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Frequency')
plt.grid(axis='y')

# Second Subplot (15 Bins)
plt.subplot(3, 1, 2)
plt.hist(temperature_data, bins=15, color='lightgreen', edgecolor='black')
plt.title('Bins: 15')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Frequency')
plt.grid(axis='y')

# Third Subplot (20 Bins)
plt.subplot(3, 1, 3)
plt.hist(temperature_data, bins=20, color='salmon', edgecolor='black')
plt.title('Bins: 20')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Frequency')
plt.grid(axis='y')

# Add a common title for the entire figure
plt.suptitle('Temperature Histograms', fontsize=12)

# Adjust spacing between subplots
plt.tight_layout(rect=[0, 0, 1, 0.9])

# Show the subplots
plt.show()

# %% [markdown]
# # Activity 2. Exploring Stock Market Data and Looking for Trends
#
# Welcome to the 'Exploring Stock Market Data' activity. In this exercise, students will embark on a journey into the world of financial data analysis. They will examine historical stock prices, seeking to uncover valuable insights that can inform investment decisions. This activity invites participants to explore the numbers and patterns behind stock performance, gaining valuable skills in the process.
#
# <br>
#
# First, write a code that allows you to access the information contained in the csv file in the form of a pandas dataframe.
#
# Remember that each time you exit the collab you must upload the csv file again.

# %%
df2 = pd.read_csv("Stocks.csv")

df2.head()
# Out:
#          Date Symbol   Open   High    Low   Close    Volume
# 0  2022-01-03   AAPL  150.0  152.8  149.5  152.45  12345678
# 1  2022-01-04   AAPL  152.5  153.2  150.8  152.80  13456789
# 2  2022-01-05   AAPL  152.8  153.5  151.9  152.25  11234567
# 3  2022-01-06   AAPL  152.3  153.4  151.6  153.15   9876543
# 4  2022-01-07   AAPL  153.2  153.6  151.7  153.30  10987654

# %% [markdown]
# You can see that the dataframe has different columns, and each one represents the following:
#
# * **Date:** It is the day for which the behavior of the stock was observed.
#
# * **Symbol:** It is the name of the stock AAPL for Apple Inc. and GOOGL for the company Google.
#
# * **Open:** It is the initial price of the stock on the day
#
# * **High:** The maximum price of the day reached by the stock
#
# * **Low:** The lowest price of the day reached by the stock
#
# * **Close:** It is the price at the end of the day
#
# * **Volume:** The total number of shares bought or sold during the day

# %% [markdown]
# It is recommended to sort your dataframe by date in ascending order and reset the index in this way. So that data zero matches the first date recorded. To do this you can use the following syntax
#
#
#
# ```
# df2 = df2.sort_values(by='Date')
# df2 = df2.reset_index(drop=True)
# ```

# %%
# Sort the DataFrame by the 'date' column in ascending order
df2 = df2.sort_values(by='Date')

# Reset the index, starting from the oldest date
df2 = df2.reset_index(drop=True)

# %%
df2.head()
# Out:
#          Date Symbol    Open    High     Low    Close    Volume
# 0  2022-01-03   AAPL   150.0   152.8   149.5   152.45  12345678
# 1  2022-01-03  GOOGL  2700.0  2720.5  2688.2  2715.90   2345678
# 2  2022-01-04   AAPL   152.5   153.2   150.8   152.80  13456789
# 3  2022-01-04  GOOGL  2721.0  2735.4  2705.8  2725.20   3456789
# 4  2022-01-05   AAPL   152.8   153.5   151.9   152.25  11234567

# %% [markdown]
# To get a better insight into this information, it is important to use graphs that allow you to observe data trends. To do so, please follow the steps below which indicate which graphs you should make and what you should keep in mind.

# %% [markdown]
# ## Task A: Line plot
#
# One of the fastest ways to analyze the trend of the data is through a line graph over time, since it allows to observe how the data changes in a specific interval. It also serves to estimate whether the value will increase or decrease in the future, with some accuracy, although this is not always the case.
#
# <br>
#
# To begin with, make a line chart of the stock volume for the month of February, using one line for each company:
#
# * Use a blue color to represent apple shares and a red color to represent google shares.
#
# * Be sure to add style to the graphic, and add titles to the axes

# %%
# Filter data for the month of February
february_data = df2[(df2['Date'] >= '2022-02-01') & (df2['Date'] <= '2022-02-28')]

# Separate data for Apple and Google
aapl_data = february_data[february_data['Symbol'] == 'AAPL']
googl_data = february_data[february_data['Symbol'] == 'GOOGL']

# Create a line chart for Apple's stock volume (blue color)
plt.plot(aapl_data['Date'], aapl_data['Volume'], color='blue', linestyle='--', label='AAPL')

# Create a line chart for Google's stock volume (red color)
plt.plot(googl_data['Date'], googl_data['Volume'], color='red', linestyle='-.', label='GOOGL')

# Customize the chart
plt.title('Stock Volume for AAPL and GOOGL in February 2022')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.xticks(rotation = 90)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# Show the chart
plt.show()

# %% [markdown]
# * Which stock do you think has lost the most value?
# * Which stock do you think will continue to grow?
# * Do you think there may be outliers in any of the curves? How would they affect the results?

# %% [markdown]
# * In this case, it is evident that the trading volume for Google is significantly lower than that of Apple. This observation could suggest that the value of Google stock has been experiencing a increase over time.
#
# * However, it's important to note that the trading volume for Apple has been decreasing much more rapidly in the last days compared to Google. This trend might persist, potentially leading to a further decrease in Apple's trading volume in the coming days.
#
# * It is highly likely that the two spikes in the Apple line are caused by outliers. As you can see, they can complicate the identification of trends and distort the data.

# %% [markdown]
# ## Task B - Data Distribution and Outliers
#
# In this exercise, let's dive into the world of data distribution. We'll be focusing on the closing prices of a chosen company's stock (for example, Apple - AAPL) from our dataset.
#
# <br>
#
#
# Histograms and boxplots are essential in data analysis for visualizing data distribution, identifying outliers, and making informed modeling decisions. They provide concise summaries, aiding in effective data exploration and communication.
#
# <br>
#
#
# Your task is to create both a histogram and a boxplot to gain insights into how these closing prices are distributed.
#
# To do so, use the **subplot** tool of matplotlib and plot the two boxes side by side.

# %%
# Filter data for Apple (AAPL)
aapl_data = df2[df2['Symbol'] == 'AAPL']

# Create subplots with two columns
plt.figure(figsize=(12, 5))

# Plot a histogram on the first subplot
plt.subplot(1, 2, 1)
plt.hist(aapl_data['Close'], bins=25, color='blue')
plt.title('Histogram of AAPL Closing Prices')
plt.xlabel('Closing Price')
plt.ylabel('Frequency')

# Plot a boxplot on the second subplot
plt.subplot(1, 2, 2)
plt.boxplot(aapl_data['Close'])
plt.title('Boxplot of AAPL Closing Prices')
plt.xlabel('Closing Price')

# Adjust spacing between subplots
plt.tight_layout()

# Show the subplots
plt.show()

# %% [markdown]
# * What information can you extract from these graphs?
# * Does it make it easier to identify outliers?
# * What do the boxplot lines represent?

# %% [markdown]
# * By using a histogram it is possible to see in which range most of the values are concentrated and how often they are found. And by using a Boxplot it is possible to see how the data is distributed with respect to the median.
# * These graphs facilitate the recognition of outliers, since they focus on observing the properties of the majority of the data, and highlight those that do not fall within these ranges.
#
# * The orange line represents the median of the data, while the box represents the quartiles (but this is not very important). The circles outside the box plot are the outliers of the distribution.

# %% [markdown]
# ## Task C - Relation Between Variables
#
# Scatter plots are like maps for data. They help us see how two things are connected by placing dots on a graph. By looking at these dots, we can find patterns or important points in the data, which can be quite useful for making informed decisions.
#
# <br>
#
# To complete this task, create a scatter plot between the closing price of the stock and the volume of the google company. Remember to customize your chart and add names and titles.

# %%
# Filter data for Google (GOOGL)
googl_data = df2[df2['Symbol'] == 'GOOGL']

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(googl_data['Close'], googl_data['Volume'], color='blue')
plt.title('Scatter Plot of GOOGL Closing Price vs. Volume')
plt.xlabel('Closing Price')
plt.ylabel('Volume')
plt.grid(True, linestyle='--')

# Show the scatter plot
plt.show()

# %% [markdown]
# * Can you extract a trend from this data?
#
# * Is there any way to relate closing price to volume?

# %% [markdown]
# * As you can see, the higher the closing price of the stock, the lower the volume of transactions, so in this case it is possible to affirm this.  Although it does not imply that this is completely true because there is not enough market information to affirm this trend.

# %% [markdown]
# # Activity 3 - Analyzing Books with Pandas
#
# Pandas is one of the most widely used libraries in Python for data analysis due to its efficiency and the large number of functions it has to perform operations with datasets.
#
# <br>
#
# The following activity belongs to the analyzing Books with pandas module. Therefore, the activities in this section will consist of writing snippets to extract specific information from the dataset.
#
# [Treehouse Module](https://teamtreehouse.com/library/analyzing-books-with-pandas)
#
# <br>
#
# First, write a code that allows you to access the information contained in the csv file in the form of a pandas dataframe.
#
# Remember that each time you exit the collab you must upload the csv file again.

# %%
books = pd.read_csv("books.csv")

books.head()
# Out:
#    bookID                                  title              authors  \
# 0       1  Harry Potter and the Sorcerer's Stone         J.K. Rowling
# 1       2                  To Kill a Mockingbird           Harper Lee
# 2       3                       The Great Gatsby  F. Scott Fitzgerald
# 3       4                    Pride and Prejudice          Jane Austen
# 4       5                                   1984        George Orwell
#
#    average_rating        isbn         isbn13 language_code  num_pages  \
# 0            4.47  0439554934  9780439554933           eng        309
# 1            4.07  0061120081  9780061120084           eng        324
# 2            3.91  0743273567  9780743273565           eng        180
# 3            4.26  0679783261  9780679783268           eng        279
# 4            4.18  0451524934  9780451524935           eng        268
#
#    ratings_count  text_reviews_count publication_date  \
# 0         730120                9422        6/26/1997
# 1        4144217               73572        7/11/1960
# 2        3313091               28765        9/30/2004
# 3        2816153               23509       10/10/2000
# 4        2436332               26497         1/1/1950
#
#                           publisher
# 0                   Scholastic Inc.
# 1  Harper Perennial Modern Classics
# 2                          Scribner
# 3                    Modern Library
# 4                            Signet

# %% [markdown]
# The tasks to be carried out are:
#
# A. Find the most popular book(The book with the highest number of reviews) of the autor: "J.K. Rowling"

# %%
# Filter the dataset for books by the specified author
author_books = books[books['authors'] == 'J.K. Rowling']

# Sort the filtered dataset by ratings_count in descending order
sorted_author_books = author_books.sort_values(by='ratings_count', ascending=False)

# Get the most popular book (top entry)
sorted_author_books.head(1)
# Out:
#     bookID                                    title       authors  \
# 40      41  Harry Potter and the Chamber of Secrets  J.K. Rowling
#
#     average_rating        isbn         isbn13 language_code  num_pages  \
# 40             4.4  0439064872  9780439064873           eng        341
#
#     ratings_count  text_reviews_count publication_date        publisher
# 40        2068223               19088       1999-06-02  Scholastic Inc.

# %% [markdown]
# B. Find the top 5 highest rated books between the years 2000 and 2010
#
#
# Remember to change first the 'publication_date' column to a pandas date type, and check the function Timestamp
# ```
# books['publication_date'] = pd.to_datetime(books['publication_date'])
#
# pd.Timestamp()
# ```
#
# [Treehouse link](https://teamtreehouse.com/library/analyzing-books-with-pandas/popularity)
#
# [Timestamp documentation](https://pandas.pydata.org/docs/reference/api/pandas.Timestamp.html)

# %%
# Convert the "publication_date" column to datetime
books['publication_date'] = pd.to_datetime(books['publication_date'])

# Filter the dataset for books published between 2000 and 2010
filtered_books = books[(books['publication_date'] >= pd.Timestamp(2000,1,1) ) & (books['publication_date'] <= pd.Timestamp(2010,12,31))]

  #Alternative: filtered_books = books[(books['publication_date'].dt.year >= 2000) & (books['publication_date'].dt.year <= 2010)]

# Sort the filtered dataset by average_rating in descending order
sorted_books = filtered_books.sort_values(by='average_rating', ascending=False)

# Retrieve the top 5 highest-rated books
sorted_books.head(5)
# Out:
#     bookID                                     title           authors  \
# 42      43       Harry Potter and the Goblet of Fire      J.K. Rowling
# 41      42  Harry Potter and the Prisoner of Azkaban      J.K. Rowling
# 13      14                                  The Help  Kathryn Stockett
# 10      11                            The Book Thief      Markus Zusak
# 23      24                           The Kite Runner   Khaled Hosseini
#
#     average_rating        isbn         isbn13 language_code  num_pages  \
# 42            4.57  0439139597  9780439139595           eng        734
# 41            4.55  043965548X  9780439655484           eng        435
# 13            4.45  0399155341  9780399155345           eng        464
# 10            4.36  0375831002  9780375831003           eng        552
# 23            4.29  159463193X  9781594631931           eng        324
#
#     ratings_count  text_reviews_count publication_date        publisher
# 42        1761399               12363       2002-09-28       Scholastic
# 41        1996446               13556       2004-08-15       Scholastic
# 13        1775351               76382       2009-02-10     Putnam Adult
# 10        1780196               53693       2006-03-14  Alfred A. Knopf
# 23        2681415               64647       2003-05-29  Riverhead Books

# %% [markdown]
# C. Which book has the most pages?

# %%
# Find the book with the highest number of pages
book_with_most_pages = books[books['num_pages'] == books['num_pages'].max()]

book_with_most_pages
# Out:
#     bookID               title            authors  average_rating        isbn  \
# 15      16  Gone with the Wind  Margaret Mitchell             4.3  0446675539
#
#            isbn13 language_code  num_pages  ratings_count  text_reviews_count  \
# 15  9780446675536           eng       1037         947718               15952
#
#    publication_date                 publisher
# 15       1936-06-30  Grand Central Publishing

# %% [markdown]
# D. Find all books published in 2002 before October 31.

# %%
#Filter using timestamp
books[(books['publication_date'] >= pd.Timestamp(2002,1,1) ) & (books['publication_date'] <= pd.Timestamp(2002,10,31))]
# Out:
#     bookID                                title            authors  \
# 12      13                            The Giver         Lois Lowry
# 18      19                            Middlesex  Jeffrey Eugenides
# 24      25              The Secret Life of Bees      Sue Monk Kidd
# 42      43  Harry Potter and the Goblet of Fire       J.K. Rowling
#
#     average_rating        isbn         isbn13 language_code  num_pages  \
# 12            4.13  0385732554  9780385732550           eng        208
# 18            3.99  0312427735  9780312427735           eng        529
# 24            4.03  0671525437  9780671525436           eng        302
# 42            4.57  0439139597  9780439139595           eng        734
#
#     ratings_count  text_reviews_count publication_date   publisher
# 12        1592052               57915       2002-09-01       Ember
# 18         498905               25763       2002-09-04     Picador
# 24        1231967               17150       2002-01-28      Viking
# 42        1761399               12363       2002-09-28  Scholastic

# %% [markdown]
# E. Find the average number of pages written by 'J.K. Rowling' per book

# %%
#Treehouse solution

pages = books.loc[books['authors'] == 'J.K. Rowling', 'num_pages'].sum()
n_books = (books['authors'] == 'J.K. Rowling').value_counts()[1]
avg_pages = pages/n_books
print(avg_pages)
# Out:
# 454.75

# %%
#Alternative Solution

# Filter the dataset for books by the specified author
author_books = books[books['authors'] == 'J.K. Rowling']

# Calculate the average number of pages for the author's books
average_pages = author_books['num_pages'].mean()

print(average_pages)
# Out:
# 454.75
